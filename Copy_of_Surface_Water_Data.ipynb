# %% [markdown]
# <a href="https://colab.research.google.com/github/cu-esiil-edu/MSUDenver-DineWaterQuality2023/blob/main/Copy_of_Surface_Water_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy import nan
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#Individual Files
Pb_data = pd.read_csv("/Pb-Results.csv")
Al_data = pd.read_csv("/Al-results.csv")
Fe_data = pd.read_csv("/Fe-results.csv")
Mn_data = pd.read_csv("/Mn-results.csv")
As_data = pd.read_csv("/As-Results.csv")

# %%
#Pb_data.info()
#Pb_data.head()
#Pb_data.describe()


print(Pb_data, "Date")

Pb_data_2015_2022.index
# Out:
#            Date  ResultMeasureValue UnitOld  Result  Unit
# 0    2005-03-17                 0.0    mg/L     0.0  ug/L
# 1    2005-03-22                 0.0    mg/L     0.0  ug/L
# 2    2005-04-05                 0.0    mg/L     0.0  ug/L
# 3    2005-04-13                 0.0    mg/L     0.0  ug/L
# 4    2005-04-21                 0.0    mg/L     0.0  ug/L
# ..          ...                 ...     ...     ...   ...
# 994         NaN                 NaN     NaN     NaN   NaN
# 995         NaN                 NaN     NaN     NaN   NaN
# 996         NaN                 NaN     NaN     NaN   NaN
# 997         NaN                 NaN     NaN     NaN   NaN
# 998         NaN                 NaN     NaN     NaN   NaN
#
# [999 rows x 5 columns] Date
# RangeIndex(start=0, stop=999, step=1)

# %%
#Drop Na attempt

Pb_data_drop = Pb_data.dropna()

Pb_data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 332
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                333 non-null    object
#  1   ResultMeasureValue  333 non-null    float64
#  2   UnitOld             333 non-null    object
#  3   Result              333 non-null    float64
#  4   Unit                333 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 15.6+ KB

# %%
#Data manipulation for Pb


Pb_data_2015_2022 =  pd.read_csv("/Pb-Results.csv", parse_dates=['Date'], index_col = ['Date'], na_values=['NaN'])
Pb_data_2015_2022.reset_index()



#Data Subset
Pb_data_2015_2022_Sub = Pb_data_2015_2022['2005-03-17':'2022-06-14']
Pb_data_15_22_clean= Pb_data_2015_2022_Sub.dropna()
Pb_data_15_22_month= Pb_data_15_22_clean.resample("M").max()
Pb_data_15_22_month_clean = Pb_data_15_22_month.dropna()
Pb_data_15_22_Final = Pb_data_15_22_month_clean.reset_index()

#Pb_data_2015_2022_Sub.head()
#Pb_data_15_22_clean.head()
#Pb_data_15_22_clean.index()
#Pb_data_15_22_clean.describe()
#Pb_data_15_22_FINAL.info()

#Pb_data_15_22_Final

# %%
#Data manipulation for Al


Al_data_2015_2022 =  pd.read_csv("/Al-results.csv", parse_dates=['Date'], index_col = ['Date'], na_values=['NaN'])
Al_data_2015_2022.reset_index()



#Data Subset
Al_data_2015_2022_Sub = Al_data_2015_2022['2005-04-13':'2022-06-14']
Al_data_15_22_clean= Al_data_2015_2022_Sub.dropna()
Al_data_15_22_month= Al_data_15_22_clean.resample("M").max()
Al_data_15_22_month_clean = Al_data_15_22_month.dropna()
Al_data_15_22_Final = Al_data_15_22_month_clean.reset_index()

#Al_data_15_22_Final

# %%
#Data manipulation for Fe


Fe_data_2015_2022 =  pd.read_csv("/Fe-results.csv", parse_dates=['Date'], index_col = ['Date'], na_values=['NaN'])
Fe_data_2015_2022.reset_index()



#Data Subset
Fe_data_2015_2022_Sub = Fe_data_2015_2022['2005-04-13':'2022-06-14']
Fe_data_15_22_clean= Fe_data_2015_2022_Sub.dropna()
Fe_data_15_22_month= Fe_data_15_22_clean.resample("M").max()
Fe_data_15_22_month_clean = Fe_data_15_22_month.dropna()
Fe_data_15_22_Final = Fe_data_15_22_month_clean.reset_index()

#Fe_data_15_22_Final

# %%
#Data manipulation for Mn


Mn_data_2015_2022 =  pd.read_csv("/Mn-results.csv", parse_dates=['Date'], index_col = ['Date'], na_values=['NaN'])
Mn_data_2015_2022.reset_index()



#Data Subset
Mn_data_2015_2022_Sub = Mn_data_2015_2022['2005-04-13':'2022-06-14']
Mn_data_15_22_clean= Mn_data_2015_2022_Sub.dropna()
Mn_data_15_22_month= Mn_data_15_22_clean.resample("M").max()
Mn_data_15_22_month_clean = Mn_data_15_22_month.dropna()
Mn_data_15_22_Final = Mn_data_15_22_month_clean.reset_index()

#Mn_data_15_22_Final

# %%
#Data manipulation for As


As_data_2015_2022 =  pd.read_csv("/As-Results.csv", parse_dates=['Date'], index_col = ['Date'], na_values=['NaN'])
As_data_2015_2022.reset_index()



#Data Subset
As_data_2015_2022_Sub = As_data_2015_2022['2005-04-13':'2022-06-14']
As_data_15_22_clean= As_data_2015_2022_Sub.dropna()
As_data_15_22_month= As_data_15_22_clean.resample("M").max()
As_data_15_22_month_clean = As_data_15_22_month.dropna()
As_data_15_22_Final = As_data_15_22_month_clean.reset_index()

#As_data_15_22_Final

# %%
#Test Sub set graph

Pb_data_15_22_FINAL.reset_index().plot(x= "Date", y= "Result")
# Out:
# <Axes: xlabel='Date'>

# %%
#Pb Levels Max Graph
fig, ax = plt.subplots(figsize=(17,6))
Pb_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Maximum Monthly Lead Readings (Pb)", color = "red", fontsize = 15)
plt.axhline(y = 15, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Pb Levels (ppb)", xlabel ="Date")
#Legend
plt.legend(['Lead (Pb)', '15 ppb Limit'], loc = 'upper left', frameon= False, fontsize = 15)
#Date Format
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)

#Al Levels Max Graph
fig2, ax = plt.subplots(figsize=(17,6))
Al_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Maximum Monthly Aluminium Readings (Al)", color = "Blue", fontsize = 15)
plt.axhline(y = 200, color = 'r', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Al Levels (ppb)", xlabel ="Date")
#Legend
plt.legend(['Aluminium (Al)','200 ppb Limit'], loc = 'upper left', frameon= False, fontsize = 15)
#Date Format
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)


#Fe Levels Max Graph
fig3, ax = plt.subplots(figsize=(17,6))
Fe_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Maximum Monthly Iron Readings (Fe)", color = "Green", fontsize = 15)
plt.axhline(y = 300, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Fe Levels (ppb)", xlabel ="Date")
#Legend
plt.legend(['Iron (Fe)', '300 ppb Limit'], loc = 'upper left', frameon= False, fontsize = 15)
#Date Format
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)


#Mn Levels Max Graph
fig4, ax = plt.subplots(figsize=(17,6))
Mn_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Maximum Monthly Manganese Readings (Mn)", color = "Purple", fontsize = 15)
plt.axhline(y = 50, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Mn Levels (ppb)", xlabel ="Date")
#Legend
plt.legend(['Manganese (Mn)', '50 ppb Limit'], loc = 'upper left', frameon= False, fontsize = 15)
#Date Format
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)


#As Levels Max Graph
fig5, ax = plt.subplots(figsize=(17,6))
As_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Maximum Monthly Arsenic Readings (As)", color = "Orange", fontsize = 15)
plt.axhline(y = 10, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "As Levels (ppb)", xlabel ="Date")
#Legend
plt.legend(['Arsenic (As)','10 ppb Limit'], loc = 'upper left', frameon= False, fontsize = 15)
#Date Format
date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)

# %%
#Log scale test

# %%
#Pb Levels Max Graph TEST
fig, ax = plt.subplots(figsize=(17,6))
Pb_data_15_22_Final.plot(x= "Date", y= "Result", ax = ax, title ="Pb Results", color = "red", fontsize = 15)
plt.axhline(y = 15, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Pb Levels (ug/L)", xlabel ="Date")
#Legend
plt.legend(['Lead (Pb)'], loc = 'upper left', frameon= False, fontsize = 15)

date_form = DateFormatter("%m-%d-%y")
ax.xaxis.set_major_formatter(date_form)

# %%
#GRAPHS
#Pb Levels Initial Graph
fig, ax = plt.subplots(figsize=(17,6))
Pb_data.plot(x= "Date", y= "Result", ax = ax, title ="Pb Results", color = "red")
plt.axhline(y = 15, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Pb Levels (ug/L)", xlabel ="Date")

#Al Levels Initial Graph
fig2, ax = plt.subplots(figsize=(17,6))
Al_data.plot(x= "Date", y= "Result", ax = ax, title ="Al Results", color = "Blue")
plt.axhline(y = 200, color = 'r', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Al Levels (ug/L)", xlabel ="Date")

#Fe Levels Initial Graph
fig3, ax = plt.subplots(figsize=(17,6))
Fe_data.plot(x= "Date", y= "Result", ax = ax, title ="Fe Results", color = "Green")
plt.axhline(y = 300, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Fe Levels (ug/L)", xlabel ="Date")

#Mn Levels Initial Graph
fig4, ax = plt.subplots(figsize=(17,6))
Mn_data.plot(x= "Date", y= "Result", ax = ax, title ="Mn Results", color = "Purple")
plt.axhline(y = 50, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "Mn Levels (ug/L)", xlabel ="Date")

#As Levels Initial Graph
fig5, ax = plt.subplots(figsize=(17,6))
As_data.plot(x= "Date", y= "Result", ax = ax, title ="As Results", color = "Orange")
plt.axhline(y = 10, color = 'b', linestyle = 'dashed')
#Labels
ax.set(ylabel = "As Levels (ug/L)", xlabel ="Date")





plt.show()

# %%
#Pb Levels Initial Graph (TEST GRAPH)
fig, ax = plt.subplots(figsize=(15,6))
#x_axis = ['10']
Pb_data.plot(x= "Date", y= "Result", ax = ax, title ="Pb Results", color = "red")
plt.axhline(y = 10, color = 'b', linestyle = '-')
#plt.xlim("2005-03-17","2017-04-03")
#Labels
ax.set(ylabel = "Pb Levels (ug/L)", xlabel ="Date")

plt.show()

# %%
#As Levels Initial Graph
fig6, ax = plt.subplots(figsize=(25,17))
As_data.plot(x= "Date", y= "Result", ax = ax, title ="As, Mn, Pb, Al, Fe Results", color = "Orange")
Mn_data.plot(x= "Date", y= "Result", ax = ax, color = "Purple")
Pb_data.plot(x= "Date", y= "Result", ax = ax, color = "red")
Al_data.plot(x= "Date", y= "Result", ax = ax, color = "Blue")
Fe_data.plot(x= "Date", y= "Result", ax = ax, color = "Green")

#Labels
ax.set(ylabel = "Levels (ug/L)", xlabel ="Date")

#Legend

plt.legend(['As', 'Mn', 'Pb', 'Al', 'Fe'], loc = 'upper left', frameon= False, fontsize = 25)

#Axis Limits



plt.show()
